# %% [markdown]
# # Import Necessary Libraries
#  * The code imports necessary libraries for data analysis and visualization, including pandas, numpy, matplotlib, and seaborn.
#  * Pandas is commonly used for data manipulation and analysis.
#  * NumPy is used for numerical computations.
#  * Matplotlib and Seaborn are popular libraries for data visualization.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt     
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv(r"C:\Users\adity\Documents\Python Script\file handle\EDA\Global_SuperStore_16.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Row ID                  Order ID  Order Date   Ship Date  \
# 0           0   40098  CA-2014-AB10015140-41954  2014-11-11  2014-11-13
# 1           1   26341    IN-2014-JR162107-41675  2014-02-05  2014-02-07
# 2           2   25330    IN-2014-CR127307-41929  2014-10-17  2014-10-18
# 3           3   13524   ES-2014-KM1637548-41667  2014-01-28  2014-01-30
# 4           4   47221   SG-2014-RH9495111-41948  2014-11-05  2014-11-06
#
#       Ship Mode   Customer ID     Customer Name      Segment  Postal Code  \
# 0   First Class  AB-100151402     Aaron Bergman     Consumer      73120.0
# 1  Second Class     JR-162107     Justin Ritter    Corporate          NaN
# 2   First Class     CR-127307      Craig Reiter     Consumer          NaN
# 3   First Class    KM-1637548  Katherine Murray  Home Office          NaN
# 4      Same Day    RH-9495111       Rick Hansen     Consumer          NaN
#
#    ...    Category Sub-Category                               Product Name  \
# 0  ...  Technology       Phones                           Samsung Convoy 3
# 1  ...   Furniture       Chairs  Novimex Executive Leather Armchair, Black
# 2  ...  Technology       Phones          Nokia Smart Phone, with Caller ID
# 3  ...  Technology       Phones             Motorola Smart Phone, Cordless
# 4  ...  Technology      Copiers             Sharp Wireless Fax, High-Speed
#
#       Sales Quantity Discount    Profit Shipping Cost Order Priority  Returned
# 0   221.980        2      0.0   62.1544         40.77           High       NaN
# 1  3709.395        9      0.1 -288.7650        923.63       Critical       NaN
# 2  5175.171        9      0.1  919.9710        915.49         Medium       NaN
# 3  2892.510        5      0.1  -96.5400        910.16         Medium       NaN
# 4  2832.960        8      0.0  311.5200        903.04       Critical       NaN
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (51290, 26)

# %% [markdown]
# The dataset contains 51,290 rows and 24 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51290 non-null  int64
#  1   Row ID          51290 non-null  int64
#  2   Order ID        51290 non-null  object
#  3   Order Date      51290 non-null  object
#  4   Ship Date       51290 non-null  object
#  5   Ship Mode       51290 non-null  object
#  6   Customer ID     51290 non-null  object
#  7   Customer Name   51290 non-null  object
#  8   Segment         51290 non-null  object
#  9   Postal Code     9994 non-null   float64
#  10  City            51290 non-null  object
#  11  State           51290 non-null  object
#  12  Country         51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Market          51290 non-null  object
#  15  Product ID      51290 non-null  object
#  16  Category        51290 non-null  object
#  17  Sub-Category    51290 non-null  object
#  18  Product Name    51290 non-null  object
#  19  Sales           51290 non-null  float64
#  20  Quantity        51290 non-null  int64
#  21  Discount        51290 non-null  float64
#  22  Profit          51290 non-null  float64
#  23  Shipping Cost   51290 non-null  float64
#  24  Order Priority  51290 non-null  object
#  25  Returned        2202 non-null   object
# dtypes: float64(5), int64(3), object(18)
# memory usage: 10.2+ MB

# %%
df.nunique()
# Out:
# Unnamed: 0        51290
# Row ID            51290
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             26080
# Quantity             14
# Discount             28
# Profit            27675
# Shipping Cost     16558
# Order Priority        4
# Returned              1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# Returned          49088
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("Global_SuperStore_16.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  Order Date     Ship Mode     Customer Name      Segment  \
# 0           0  2014-11-11   First Class     Aaron Bergman     Consumer
# 1           1  2014-02-05  Second Class     Justin Ritter    Corporate
# 2           2  2014-10-17   First Class      Craig Reiter     Consumer
# 3           3  2014-01-28   First Class  Katherine Murray  Home Office
# 4           4  2014-11-05      Same Day       Rick Hansen     Consumer
#
#             City            State        Country          Region  \
# 0  Oklahoma City         Oklahoma  United States      Central US
# 1     Wollongong  New South Wales      Australia         Oceania
# 2       Brisbane       Queensland      Australia         Oceania
# 3         Berlin           Berlin        Germany  Western Europe
# 4          Dakar            Dakar        Senegal  Western Africa
#
#          Market  ... Discount  Profit Shipping Cost  Order Priority  Returned  \
# 0          USCA  ...        0   62.15         40.77            High        No
# 1  Asia Pacific  ...       10 -288.76        923.63        Critical        No
# 2  Asia Pacific  ...       10  919.97        915.49          Medium        No
# 3        Europe  ...       10  -96.54        910.16          Medium        No
# 4        Africa  ...        0  311.52        903.04        Critical        No
#
#    Year  Month  Total Sales Total Profit Total Shipping Cost
# 0  2014     11       443.96       124.31               81.54
# 1  2014      2    33,384.56    -2,598.88            8,312.67
# 2  2014     10    46,576.54     8,279.74            8,239.41
# 3  2014      1    14,462.55      -482.70            4,550.80
# 4  2014     11    22,663.68     2,492.16            7,224.32
#
# [5 rows x 25 columns]

# %% [markdown]
# # Data Reduction

# %%
df['Discount']=df['Discount']*100
df['Discount']=df['Discount'].astype('int')

# %%
df[['Sales','Quantity','Discount','Profit','Shipping Cost']].head()
# Out:
#       Sales  Quantity  Discount    Profit  Shipping Cost
# 0   221.980         2         0   62.1544          40.77
# 1  3709.395         9        10 -288.7650         923.63
# 2  5175.171         9        10  919.9710         915.49
# 3  2892.510         5        10  -96.5400         910.16
# 4  2832.960         8         0  311.5200         903.04

# %% [markdown]
# Removes several columns from the 'Gsma' DataFrame

# %%
df.drop(['Row ID', 'Order ID', 'Ship Date', 'Customer ID', 'Postal Code', 'Product Name'], axis=1, inplace = True)

# %% [markdown]
# Fills missing values in the 'Returned' column of the 'Gsma' DataFrame with the string 'No'

# %%
df['Returned'].fillna('No', inplace=True)

# %%
df.shape
# Out:
# (51290, 20)

# %% [markdown]
# ## Fearture Engineering ##
# * Year': Extracted from the 'Order Date' column, representing the year of the order.
# * 'Month': Extracted from the 'Order Date' column, representing the month of the order.
# * 'Cost': Calculated as the difference between 'Sales' and 'Profit', representing the cost incurred.
# * 'Total Amount': Calculated as the sum of 'Sales' and 'Shipping Cost', representing the total amount including shipping cost.

# %%
df['Year']=pd.DatetimeIndex(df['Order Date']).year
df['Month']=pd.DatetimeIndex(df['Order Date']).month

# %%
df['Total Sales'] = df['Sales'] * df['Quantity']

df['Total Profit'] = df['Profit'] * df['Quantity']

df['Total Shipping Cost'] = df['Shipping Cost'] * df['Quantity']

# %%
df.describe().T
# Out:
#                        count          mean           std        min  \
# Unnamed: 0           51290.0  25644.500000  14806.291990      0.000
# Sales                51290.0    246.490581    487.565361      0.444
# Quantity             51290.0      3.476545      2.278766      1.000
# Discount             51290.0     14.288263     21.228409      0.000
# Profit               51290.0     28.610982    174.340972  -6599.978
# Shipping Cost        51290.0     26.478567     57.251373      1.002
# Year                 51290.0   2013.777208      1.098931   2012.000
# Month                51290.0      7.516027      3.300526      1.000
# Total Sales          51290.0   1205.327987   3452.079528      0.444
# Total Profit         51290.0    140.928945   1204.325089 -49060.512
# Total Shipping Cost  51290.0    127.513488    385.804489      1.010
#
#                               25%         50%         75%         max
# Unnamed: 0           12822.250000  25644.5000  38466.7500   51289.000
# Sales                   30.758625     85.0530    251.0532   22638.480
# Quantity                 2.000000      3.0000      5.0000      14.000
# Discount                 0.000000      0.0000     20.0000      85.000
# Profit                   0.000000      9.2400     36.8100    8399.976
# Shipping Cost            2.610000      7.7900     24.4500     933.570
# Year                  2013.000000   2014.0000   2015.0000    2015.000
# Month                    5.000000      8.0000     10.0000      12.000
# Total Sales             66.930000    245.7720    904.8750  135830.880
# Total Profit             0.000000     22.6515    123.1200   64302.810
# Total Shipping Cost      6.200000     22.6400     87.3575   11254.620

# %% [markdown]
# ## Summary Statistics:
# * The earliest order date is in 2012, and the latest is in 2015.
# * The average sales amount is approximately
# * 0.44 and a maximum of $22,638.48.
# * On average, around 3.48 items are sold per order, with a minimum of 1 and a maximum of 14.
# * The average discount offered is about 14.29%, ranging from 0% to 85%.
# * The average profit per order is
# * 6,599.98 to a profit of $8,399.98.
# * The average shipping cost is approximately
# * 1.00 and a maximum of $933.57.
# * Orders span from the year 2012 to 2015, with most orders concentrated around 2013 and 2014.
# * Most orders are placed in July, with the highest median.
# * The average cost (sales minus profit) is approximately $217.88.
# * The average total amount (sales plus shipping cost) is approximately $272.97.

# %% [markdown]
# ## Data Visualization

# %%
cat_col = df.select_dtypes(include='object').columns.tolist()
num_col = df.select_dtypes(include=np.number).columns.tolist()

print(cat_col)
print(num_col)
# Out:
# ['Order Date', 'Ship Mode', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category', 'Order Priority', 'Returned']
# ['Unnamed: 0', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Year', 'Month', 'Total Sales', 'Total Profit', 'Total Shipping Cost']

# %%
for col in num_col:
    plt.subplot(1,1,1)
    df[col].hist(bins=10, alpha=0.5,edgecolor='red',grid=False)
    plt.ylabel('Frequency')
    plt.title(col,fontsize=12,fontweight='bold',color='green')
    plt.show()

# %% [markdown]
# * Most orders consist of 1 to 5 items, with 2 being the most common quantity.
# * Discounts of 20%, 10%, 40%, and 60% are among the most common.
# * Profits vary widely, ranging from significant profits to losses. A considerable number of orders result in zero profit.
# * Most common shipping costs include
# * Orders are distributed across the years 2012 to 2015, with 2015 having the highest number of orders
# * Orders are spread across different months, with November and December having the highest number of orders.

# %%
for col in cat_col:
    plt.figure()  
    sns.countplot(x=col, data=df, order=df[col].value_counts().head(10).index, palette='summer')
    plt.xticks(rotation=90)
    plt.title(col,fontsize=12,fontweight='bold',color='green')
    plt.show()

# %% [markdown]
# * The provided series of value counts represents the distribution of various categorical variables in the dataset.
# * Most orders are shipped using "Standard Class" (30,775 orders), followed by "Second Class" (10,309 orders), "First Class" (7,505 orders), and "Same  Day" (2,701 orders).
# * The majority of orders are from the "Consumer" segment (26,518 orders), followed by "Corporate" (15,429 orders), and "Home Office" (9,343 orders).
# * The dataset includes orders from different countries, with the majority from the "United States" (9,994 orders).
# * Orders are from different states, with "California" having the highest number of orders (2,001 orders).
# * Orders are distributed across different regions, with "Western Europe" having the highest number of orders (5,883 orders).
# * The market is segmented into different regions, with "Asia Pacific" having the highest number of orders (14,302 orders).
# * Most orders are for "Office Supplies" (31,289 orders), followed by "Technology" (10,141 orders), and "Furniture" (9,860 orders).

# %%
pd.options.display.float_format='{:,.2f}'.format

# %%
print(f'Net Sales {df['Sales'].sum()}')
# Out:
# Net Sales 12642501.90988

# %%
print(f'Net Profit {df['Profit'].sum()}')
# Out:
# Net Profit 1467457.2912799998

# %%
print(f'Gross Sales {df['Total Sales'].sum()}')
# Out:
# Gross Sales 61821272.47008

# %%
print(f'Gross Profit {df['Total Profit'].sum()}')
# Out:
# Gross Profit 7228245.59588

# %%
print(f'Profit Margin {round(df['Total Profit'].sum()/df['Total Sales'].sum() * 100)} %')
# Out:
# Profit Margin 12 %

# %%
print(f'Total Cost {df['Total Sales'].sum() - df['Total Profit'].sum() - df['Total Shipping Cost'].sum()}')
# Out:
# Total Cost 48052860.08724

# %%
print(f'Net Profit {df['Total Profit'].sum() - df['Total Shipping Cost'].sum()}')
# Out:
# Net Profit 688078.8089199997

# %%
year_analysis = df.groupby('Year').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
year_analysis.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_27fc7_row0_col0, #T_27fc7_row0_col1, #T_27fc7_row0_col2, #T_27fc7_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_27fc7_row1_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_27fc7_row1_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_27fc7_row1_col2, #T_27fc7_row1_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_27fc7_row2_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_27fc7_row2_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_27fc7_row2_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_27fc7_row2_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_27fc7_row3_col0, #T_27fc7_row3_col1, #T_27fc7_row3_col2, #T_27fc7_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_27fc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27fc7_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_27fc7_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_27fc7_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_27fc7_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27fc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27fc7_row0_col0" class="data row0 col0" >2012</td>
#       <td id="T_27fc7_row0_col1" class="data row0 col1" >2259450.895540</td>
#       <td id="T_27fc7_row0_col2" class="data row0 col2" >248940.811540</td>
#       <td id="T_27fc7_row0_col3" class="data row0 col3" >31443</td>
#     </tr>
#     <tr>
#       <th id="T_27fc7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27fc7_row1_col0" class="data row1 col0" >2013</td>
#       <td id="T_27fc7_row1_col1" class="data row1 col1" >2677438.694400</td>
#       <td id="T_27fc7_row1_col2" class="data row1 col2" >307415.279100</td>
#       <td id="T_27fc7_row1_col3" class="data row1 col3" >38111</td>
#     </tr>
#     <tr>
#       <th id="T_27fc7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27fc7_row2_col0" class="data row2 col0" >2014</td>
#       <td id="T_27fc7_row2_col1" class="data row2 col1" >3405746.449380</td>
#       <td id="T_27fc7_row2_col2" class="data row2 col2" >406935.230180</td>
#       <td id="T_27fc7_row2_col3" class="data row2 col3" >48136</td>
#     </tr>
#     <tr>
#       <th id="T_27fc7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27fc7_row3_col0" class="data row3 col0" >2015</td>
#       <td id="T_27fc7_row3_col1" class="data row3 col1" >4299865.870560</td>
#       <td id="T_27fc7_row3_col2" class="data row3 col2" >504165.970460</td>
#       <td id="T_27fc7_row3_col3" class="data row3 col3" >60622</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1,3,1)
plt.bar(year_analysis['Year'], year_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Sales by Year')
plt.xlabel('Month')
plt.ylabel('Total Sales')

plt.subplot(1,3,2)
plt.bar(year_analysis['Year'], year_analysis['Profit'], color=sns.color_palette('Set1'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Profit by Year')
plt.xlabel('Month')
plt.ylabel('Total Profit')

plt.subplot(1,3,3)
plt.bar(year_analysis['Year'], year_analysis['Quantity'], color=sns.color_palette('Set1'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Quantity Sold by Year')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Sales and profit show an increasing trend over the years, indicating positive growth in business.
# * The most significant growth is observed between 2014 and 2015, with both sales and profit substantially increasing.

# %%
monthly_data = df.groupby('Month').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).reset_index()

# %%
monthly_data.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_c72b7_row0_col0, #T_c72b7_row0_col1, #T_c72b7_row1_col2, #T_c72b7_row1_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_c72b7_row0_col2 {
#   background-color: #015b52;
#   color: #f1f1f1;
# }
# #T_c72b7_row0_col3 {
#   background-color: #004135;
#   color: #f1f1f1;
# }
# #T_c72b7_row1_col0 {
#   background-color: #016259;
#   color: #f1f1f1;
# }
# #T_c72b7_row1_col1 {
#   background-color: #004439;
#   color: #f1f1f1;
# }
# #T_c72b7_row2_col0 {
#   background-color: #6abdb2;
#   color: #000000;
# }
# #T_c72b7_row2_col1 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_c72b7_row2_col2 {
#   background-color: #01554b;
#   color: #f1f1f1;
# }
# #T_c72b7_row2_col3 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_c72b7_row3_col0 {
#   background-color: #aee0d8;
#   color: #000000;
# }
# #T_c72b7_row3_col1 {
#   background-color: #67bbb0;
#   color: #000000;
# }
# #T_c72b7_row3_col2 {
#   background-color: #3b9b93;
#   color: #f1f1f1;
# }
# #T_c72b7_row3_col3 {
#   background-color: #8dd2c7;
#   color: #000000;
# }
# #T_c72b7_row4_col0 {
#   background-color: #f5efde;
#   color: #000000;
# }
# #T_c72b7_row4_col1, #T_c72b7_row4_col2 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_c72b7_row4_col3 {
#   background-color: #79c8bc;
#   color: #000000;
# }
# #T_c72b7_row5_col0 {
#   background-color: #2b8d85;
#   color: #f1f1f1;
# }
# #T_c72b7_row5_col1 {
#   background-color: #b6e3dd;
#   color: #000000;
# }
# #T_c72b7_row5_col2 {
#   background-color: #23867e;
#   color: #f1f1f1;
# }
# #T_c72b7_row5_col3 {
#   background-color: #cbebe6;
#   color: #000000;
# }
# #T_c72b7_row6_col0 {
#   background-color: #eedbaa;
#   color: #000000;
# }
# #T_c72b7_row6_col1 {
#   background-color: #ecd8a5;
#   color: #000000;
# }
# #T_c72b7_row6_col2 {
#   background-color: #e6cd92;
#   color: #000000;
# }
# #T_c72b7_row6_col3 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_c72b7_row7_col0 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_c72b7_row7_col1, #T_c72b7_row9_col3 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_c72b7_row7_col2 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_c72b7_row7_col3 {
#   background-color: #bd7f2c;
#   color: #f1f1f1;
# }
# #T_c72b7_row8_col0 {
#   background-color: #e0f0ee;
#   color: #000000;
# }
# #T_c72b7_row8_col1 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_c72b7_row8_col2 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_c72b7_row8_col3 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_c72b7_row9_col0 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_c72b7_row9_col1 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_c72b7_row9_col2 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_c72b7_row10_col0, #T_c72b7_row11_col1, #T_c72b7_row11_col2, #T_c72b7_row11_col3 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_c72b7_row10_col1 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_c72b7_row10_col2 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_c72b7_row10_col3 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_c72b7_row11_col0 {
#   background-color: #874e0a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c72b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c72b7_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_c72b7_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_c72b7_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_c72b7_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c72b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c72b7_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_c72b7_row0_col1" class="data row0 col1" >1566662.447500</td>
#       <td id="T_c72b7_row0_col2" class="data row0 col2" >168101.707100</td>
#       <td id="T_c72b7_row0_col3" class="data row0 col3" >22147</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c72b7_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_c72b7_row1_col1" class="data row1 col1" >1546728.156160</td>
#       <td id="T_c72b7_row1_col2" class="data row1 col2" >175983.189460</td>
#       <td id="T_c72b7_row1_col3" class="data row1 col3" >22379</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c72b7_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_c72b7_row2_col1" class="data row2 col1" >1431753.403480</td>
#       <td id="T_c72b7_row2_col2" class="data row2 col2" >169705.822080</td>
#       <td id="T_c72b7_row2_col3" class="data row2 col3" >20479</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c72b7_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_c72b7_row3_col1" class="data row3 col1" >1294314.957820</td>
#       <td id="T_c72b7_row3_col2" class="data row3 col2" >154593.439420</td>
#       <td id="T_c72b7_row3_col3" class="data row3 col3" >17596</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c72b7_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_c72b7_row4_col1" class="data row4 col1" >1262080.916940</td>
#       <td id="T_c72b7_row4_col2" class="data row4 col2" >144604.768440</td>
#       <td id="T_c72b7_row4_col3" class="data row4 col3" >18009</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c72b7_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_c72b7_row5_col1" class="data row5 col1" >1185227.689720</td>
#       <td id="T_c72b7_row5_col2" class="data row5 col2" >158903.895920</td>
#       <td id="T_c72b7_row5_col3" class="data row5 col3" >16303</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c72b7_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_c72b7_row6_col1" class="data row6 col1" >915492.830880</td>
#       <td id="T_c72b7_row6_col2" class="data row6 col2" >106970.037880</td>
#       <td id="T_c72b7_row6_col3" class="data row6 col3" >13196</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c72b7_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_c72b7_row7_col1" class="data row7 col1" >760517.975960</td>
#       <td id="T_c72b7_row7_col2" class="data row7 col2" >91873.579660</td>
#       <td id="T_c72b7_row7_col3" class="data row7 col3" >10390</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c72b7_row8_col0" class="data row8 col0" >7</td>
#       <td id="T_c72b7_row8_col1" class="data row8 col1" >752306.302220</td>
#       <td id="T_c72b7_row8_col2" class="data row8 col2" >76525.695020</td>
#       <td id="T_c72b7_row8_col3" class="data row8 col3" >11046</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c72b7_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_c72b7_row9_col1" class="data row9 col1" >695978.410840</td>
#       <td id="T_c72b7_row9_col2" class="data row9 col2" >73822.418640</td>
#       <td id="T_c72b7_row9_col3" class="data row9 col3" >10466</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c72b7_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_c72b7_row10_col1" class="data row10 col1" >676788.927040</td>
#       <td id="T_c72b7_row10_col2" class="data row10 col2" >73440.459440</td>
#       <td id="T_c72b7_row10_col3" class="data row10 col3" >8872</td>
#     </tr>
#     <tr>
#       <th id="T_c72b7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c72b7_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_c72b7_row11_col1" class="data row11 col1" >554649.891320</td>
#       <td id="T_c72b7_row11_col2" class="data row11 col2" >72932.278220</td>
#       <td id="T_c72b7_row11_col3" class="data row11 col3" >7429</td>
#     </tr>
#   </

# %%
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.plot(monthly_data['Month'], monthly_data['Sales'], marker='o')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.plot(monthly_data['Month'], monthly_data['Profit'], marker='*')
plt.title('Total Profit by Month')
plt.xlabel('Month')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.plot(monthly_data['Month'], monthly_data['Quantity'], marker='o')
plt.title('Total Quantity Sold by Month')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * The analysis reveals seasonal trends, with higher sales and profit observed during the holiday months of November and December.
# * Sales tend to decline in the early months of the year, possibly due to post-holiday lull and reduced consumer spending.

# %%
Ship_Mode_analysis = df.groupby('Ship Mode').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Ship_Mode_analysis.sort_values(by='Sales', ascending=False).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_4967c_row0_col1, #T_4967c_row0_col2, #T_4967c_row0_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4967c_row1_col1 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_4967c_row1_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_4967c_row1_col3 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_4967c_row2_col1, #T_4967c_row2_col3 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_4967c_row2_col2 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_4967c_row3_col1, #T_4967c_row3_col2, #T_4967c_row3_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_4967c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4967c_level0_col0" class="col_heading level0 col0" >Ship Mode</th>
#       <th id="T_4967c_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_4967c_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_4967c_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4967c_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_4967c_row0_col0" class="data row0 col0" >Standard Class</td>
#       <td id="T_4967c_row0_col1" class="data row0 col1" >7578652.106700</td>
#       <td id="T_4967c_row0_col2" class="data row0 col2" >890596.021200</td>
#       <td id="T_4967c_row0_col3" class="data row0 col3" >107319</td>
#     </tr>
#     <tr>
#       <th id="T_4967c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4967c_row1_col0" class="data row1 col0" >Second Class</td>
#       <td id="T_4967c_row1_col1" class="data row1 col1" >2565671.681080</td>
#       <td id="T_4967c_row1_col2" class="data row1 col2" >292583.527080</td>
#       <td id="T_4967c_row1_col3" class="data row1 col3" >35724</td>
#     </tr>
#     <tr>
#       <th id="T_4967c_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_4967c_row2_col0" class="data row2 col0" >First Class</td>
#       <td id="T_4967c_row2_col1" class="data row2 col1" >1830976.138200</td>
#       <td id="T_4967c_row2_col2" class="data row2 col2" >208104.675200</td>
#       <td id="T_4967c_row2_col3" class="data row2 col3" >26039</td>
#     </tr>
#     <tr>
#       <th id="T_4967c_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_4967c_row3_col0" class="data row3 col0" >Same Day</td>
#       <td id="T_4967c_row3_col1" class="data row3 col1" >667201.983900</td>
#       <td id="T_4967c_row3_col2" class="data row3 col2" >76173.067800</td>
#       <td id="T_4967c_row3_col3" class="data row3 col3" >9230</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 3, 1)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Sales')

plt.subplot(1, 3, 2)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Profit')

plt.subplot(1, 3, 3)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Standard Class emerges as the most preferred shipping option, likely due to its balance between cost and delivery speed.
# * Same Day shipping, while accounting for fewer orders, caters to customers with urgent delivery requirements and contributes to overall customer satisfaction.

# %%
Segment_analysis = df.groupby('Segment').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Segment_analysis.sort_values(by='Sales',ascending=False).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_bff98_row0_col1, #T_bff98_row0_col2, #T_bff98_row0_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bff98_row1_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bff98_row1_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_bff98_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_bff98_row2_col1, #T_bff98_row2_col2, #T_bff98_row2_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bff98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bff98_level0_col0" class="col_heading level0 col0" >Segment</th>
#       <th id="T_bff98_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_bff98_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_bff98_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bff98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bff98_row0_col0" class="data row0 col0" >Consumer</td>
#       <td id="T_bff98_row0_col1" class="data row0 col1" >6507949.417860</td>
#       <td id="T_bff98_row0_col2" class="data row0 col2" >749239.782060</td>
#       <td id="T_bff98_row0_col3" class="data row0 col3" >92157</td>
#     </tr>
#     <tr>
#       <th id="T_bff98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bff98_row1_col0" class="data row1 col0" >Corporate</td>
#       <td id="T_bff98_row1_col1" class="data row1 col1" >3824697.521460</td>
#       <td id="T_bff98_row1_col2" class="data row1 col2" >441208.328660</td>
#       <td id="T_bff98_row1_col3" class="data row1 col3" >53565</td>
#     </tr>
#     <tr>
#       <th id="T_bff98_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bff98_row2_col0" class="data row2 col0" >Home Office</td>
#       <td id="T_bff98_row2_col1" class="data row2 col1" >2309854.970560</td>
#       <td id="T_bff98_row2_col2" class="data row2 col2" >277009.180560</td>
#       <td id="T_bff98_row2_col3" class="data row2 col3" >32590</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(Segment_analysis['Segment'], Segment_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(Segment_analysis['Segment'], Segment_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Segment')
plt.xlabel('Segment')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(Segment_analysis['Segment'], Segment_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Segmente')
plt.xlabel('Segment')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Consumer segment emerges as the primary revenue generator, indicating a large and loyal customer base.
# * Corporate segment contributes significantly to sales and profit, underscoring the importance of B2B relationships and bulk purchases.
# * Home Office segment represents a niche market with moderate sales but high-profit margins, suggesting opportunities for targeted marketing and product offerings tailored to this demographic.

# %%
City_analysis = df.groupby('City').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
City_analysis.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_5aa50_row0_col1, #T_5aa50_row0_col2, #T_5aa50_row0_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_5aa50_row1_col1 {
#   background-color: #e7f2f0;
#   color: #000000;
# }
# #T_5aa50_row1_col2 {
#   background-color: #ceece8;
#   color: #000000;
# }
# #T_5aa50_row1_col3 {
#   background-color: #44a299;
#   color: #f1f1f1;
# }
# #T_5aa50_row2_col1 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_5aa50_row2_col2 {
#   background-color: #683c07;
#   color: #f1f1f1;
# }
# #T_5aa50_row2_col3 {
#   background-color: #d8b46c;
#   color: #000000;
# }
# #T_5aa50_row3_col1 {
#   background-color: #bd7f2c;
#   color: #f1f1f1;
# }
# #T_5aa50_row3_col2 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_5aa50_row3_col3 {
#   background-color: #cfa256;
#   color: #f1f1f1;
# }
# #T_5aa50_row4_col1 {
#   background-color: #a96c1e;
#   color: #f1f1f1;
# }
# #T_5aa50_row4_col2, #T_5aa50_row5_col3, #T_5aa50_row8_col2 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_5aa50_row4_col3, #T_5aa50_row6_col2 {
#   background-color: #f4e5be;
#   color: #000000;
# }
# #T_5aa50_row5_col1 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_5aa50_row5_col2, #T_5aa50_row6_col3, #T_5aa50_row9_col1 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_5aa50_row6_col1 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_5aa50_row7_col1 {
#   background-color: #6e4007;
#   color: #f1f1f1;
# }
# #T_5aa50_row7_col2 {
#   background-color: #c99546;
#   color: #f1f1f1;
# }
# #T_5aa50_row7_col3 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_5aa50_row8_col1 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_5aa50_row8_col3 {
#   background-color: #613806;
#   color: #f1f1f1;
# }
# #T_5aa50_row9_col2 {
#   background-color: #ecd8a5;
#   color: #000000;
# }
# #T_5aa50_row9_col3 {
#   background-color: #794608;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5aa50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5aa50_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_5aa50_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_5aa50_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_5aa50_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5aa50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5aa50_row0_col0" class="data row0 col0" >New York City</td>
#       <td id="T_5aa50_row0_col1" class="data row0 col1" >256368.161000</td>
#       <td id="T_5aa50_row0_col2" class="data row0 col2" >62036.983700</td>
#       <td id="T_5aa50_row0_col3" class="data row0 col3" >3417</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5aa50_row1_col0" class="data row1 col0" >Los Angeles</td>
#       <td id="T_5aa50_row1_col1" class="data row1 col1" >175851.341000</td>
#       <td id="T_5aa50_row1_col2" class="data row1 col2" >30440.757900</td>
#       <td id="T_5aa50_row1_col3" class="data row1 col3" >2879</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5aa50_row2_col0" class="data row2 col0" >Manila</td>
#       <td id="T_5aa50_row2_col1" class="data row2 col1" >120886.948500</td>
#       <td id="T_5aa50_row2_col2" class="data row2 col2" >-11158.561500</td>
#       <td id="T_5aa50_row2_col3" class="data row2 col3" >1661</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5aa50_row3_col0" class="data row3 col0" >Seattle</td>
#       <td id="T_5aa50_row3_col1" class="data row3 col1" >119540.742000</td>
#       <td id="T_5aa50_row3_col2" class="data row3 col2" >29156.096700</td>
#       <td id="T_5aa50_row3_col3" class="data row3 col3" >1590</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5aa50_row4_col0" class="data row4 col0" >San Francisco</td>
#       <td id="T_5aa50_row4_col1" class="data row4 col1" >112669.092000</td>
#       <td id="T_5aa50_row4_col2" class="data row4 col2" >17507.385400</td>
#       <td id="T_5aa50_row4_col3" class="data row4 col3" >1935</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5aa50_row5_col0" class="data row5 col0" >Philadelphia</td>
#       <td id="T_5aa50_row5_col1" class="data row5 col1" >109077.013000</td>
#       <td id="T_5aa50_row5_col2" class="data row5 col2" >-13837.767400</td>
#       <td id="T_5aa50_row5_col3" class="data row5 col3" >1981</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5aa50_row6_col0" class="data row6 col0" >Sydney</td>
#       <td id="T_5aa50_row6_col1" class="data row6 col1" >101945.517000</td>
#       <td id="T_5aa50_row6_col2" class="data row6 col2" >16002.807000</td>
#       <td id="T_5aa50_row6_col3" class="data row6 col3" >975</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5aa50_row7_col0" class="data row7 col0" >Jakarta</td>
#       <td id="T_5aa50_row7_col1" class="data row7 col1" >94321.324200</td>
#       <td id="T_5aa50_row7_col2" class="data row7 col2" >3826.984200</td>
#       <td id="T_5aa50_row7_col3" class="data row7 col3" >1226</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5aa50_row8_col0" class="data row8 col0" >London</td>
#       <td id="T_5aa50_row8_col1" class="data row8 col1" >86945.805000</td>
#       <td id="T_5aa50_row8_col2" class="data row8 col2" >17378.715000</td>
#       <td id="T_5aa50_row8_col3" class="data row8 col3" >1033</td>
#     </tr>
#     <tr>
#       <th id="T_5aa50_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5aa50_row9_col0" class="data row9 col0" >Mexico City</td>
#       <td id="T_5aa50_row9_col1" class="data row9 col1" >85700.251760</td>
#       <td id="T_5aa50_row9_col2" class="data row9 col2" >13335.591760</td>
#       <td id="T_5aa50_row9_col3" class="data row9 col3" >1138</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(City_analysis['City'], City_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(City_analysis['City'], City_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by City')
plt.xlabel('City')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(City_analysis['City'], City_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by City')
plt.xlabel('City')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Certain cities like New York City, Los Angeles, and San Francisco emerge as key revenue generators, indicating their importance in the company's sales strategy.
# * Negative profit in cities like Manila and Philadelphia suggests the need for operational improvements or pricing adjustments to ensure profitability.
# * Understanding sales and profit by city can inform targeted marketing efforts, pricing strategies, and operational decisions to optimize performance in different markets.

# %%
State_analysis = df.groupby('State').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
State_analysis
# Out:
#                     State      Sales     Profit  Quantity
# 0                 England 485,170.97  99,907.73      5656
# 1              California 457,687.63  76,381.39      7667
# 2           Ile-de-France 317,822.54  44,055.92      3839
# 3                New York 310,876.27  74,038.55      4224
# 4         New South Wales 270,487.10  43,695.98      2921
# 5              Queensland 238,312.73  21,608.75      2665
# 6  North Rhine-Westphalia 216,451.85  42,347.87      2660
# 7                   Texas 170,188.05 -25,729.36      3724
# 8            San Salvador 153,639.40  35,883.38      2273
# 9        National Capital 152,175.36 -13,066.08      2231

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(State_analysis['State'], State_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by State')
plt.xlabel('State')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(State_analysis['State'], State_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by State')
plt.xlabel('State')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(State_analysis['State'], State_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by State')
plt.xlabel('State')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Certain states like England, California, and New York emerge as key revenue drivers, indicating their importance in the company's sales strategy.
# * Negative profit margins in markets like Texas and National Capital underscore the need for operational improvements or pricing adjustments to ensure profitability.

# %%
Country_analysis = df.groupby('Country').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
Country_analysis
# Out:
#           Country        Sales     Profit  Quantity
# 0   United States 2,297,200.86 286,397.02     37873
# 1       Australia   925,235.85 103,907.43     10673
# 2          France   858,931.08 109,029.00     10804
# 3           China   700,562.03 150,683.08      7081
# 4         Germany   628,136.19 107,190.33      7739
# 5          Mexico   621,552.65 102,453.59      9972
# 6           India   589,486.04 129,050.60      5755
# 7  United Kingdom   528,576.30 111,900.15      6161
# 8       Indonesia   404,887.50  15,608.68      5237
# 9          Brazil   359,924.86  29,686.90      6123

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(Country_analysis['Country'], Country_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by Country')
plt.xlabel('Country')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(Country_analysis['Country'], Country_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by Country')
plt.xlabel('Country')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(Country_analysis['Country'], Country_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by Country')
plt.xlabel('Country')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %%
Market_analysis = df.groupby('Market').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Market_analysis.sort_values(by='Sales', ascending=False).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_a93c8_row0_col1, #T_a93c8_row0_col3, #T_a93c8_row1_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a93c8_row0_col2 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_a93c8_row1_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_a93c8_row1_col3 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_a93c8_row2_col1 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_a93c8_row2_col2 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_a93c8_row2_col3 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_a93c8_row3_col1 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_a93c8_row3_col2 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_a93c8_row3_col3 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_a93c8_row4_col1, #T_a93c8_row4_col2, #T_a93c8_row4_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_a93c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a93c8_level0_col0" class="col_heading level0 col0" >Market</th>
#       <th id="T_a93c8_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_a93c8_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_a93c8_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a93c8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a93c8_row0_col0" class="data row0 col0" >Asia Pacific</td>
#       <td id="T_a93c8_row0_col1" class="data row0 col1" >4042658.268000</td>
#       <td id="T_a93c8_row0_col2" class="data row0 col2" >403176.038000</td>
#       <td id="T_a93c8_row0_col3" class="data row0 col3" >48597</td>
#     </tr>
#     <tr>
#       <th id="T_a93c8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a93c8_row1_col0" class="data row1 col0" >Europe</td>
#       <td id="T_a93c8_row1_col1" class="data row1 col1" >3287336.233500</td>
#       <td id="T_a93c8_row1_col2" class="data row1 col2" >449551.723500</td>
#       <td id="T_a93c8_row1_col3" class="data row1 col3" >41919</td>
#     </tr>
#     <tr>
#       <th id="T_a93c8_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_a93c8_row2_col0" class="data row2 col0" >USCA</td>
#       <td id="T_a93c8_row2_col1" class="data row2 col1" >2364129.030300</td>
#       <td id="T_a93c8_row2_col2" class="data row2 col2" >304214.411700</td>
#       <td id="T_a93c8_row2_col3" class="data row2 col3" >38706</td>
#     </tr>
#     <tr>
#       <th id="T_a93c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a93c8_row3_col0" class="data row3 col0" >LATAM</td>
#       <td id="T_a93c8_row3_col1" class="data row3 col1" >2164605.167080</td>
#       <td id="T_a93c8_row3_col2" class="data row3 col2" >221643.487080</td>
#       <td id="T_a93c8_row3_col3" class="data row3 col3" >38526</td>
#     </tr>
#     <tr>
#       <th id="T_a93c8_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_a93c8_row4_col0" class="data row4 col0" >Africa</td>
#       <td id="T_a93c8_row4_col1" class="data row4 col1" >783773.211000</td>
#       <td id="T_a93c8_row4_col2" class="data row4 col2" >88871.631000</td>
#       <td id="T_a93c8_row4_col3" class="data row4 col3" >10564</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(Market_analysis['Market'], Market_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Market')
plt.xlabel('Market')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(Market_analysis['Market'], Market_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Market')
plt.xlabel('Market')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(Market_analysis['Market'], Market_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Market')
plt.xlabel('Market')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * The Asia Pacific market emerges as the primary revenue driver, indicating its critical importance in the company's sales strategy and market dominance.
# * Europe and USCA markets also show significant sales and profit, suggesting opportunities for growth and expansion in these regions.
# * Understanding sales and profit by market can inform strategic decisions regarding resource allocation, market-specific initiatives, and expansion strategies to optimize performance and maximize profitability.

# %%
Product_analysis = df.groupby('Product ID').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
Product_analysis.style.background_gradient(cmap='Grays')
# Out:
# <style type="text/css">
# #T_1866f_row0_col1, #T_1866f_row0_col3, #T_1866f_row4_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1866f_row0_col2 {
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_1866f_row1_col1 {
#   background-color: #565656;
#   color: #f1f1f1;
# }
# #T_1866f_row1_col2 {
#   background-color: #636363;
#   color: #f1f1f1;
# }
# #T_1866f_row1_col3 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# #T_1866f_row2_col1 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_1866f_row2_col2 {
#   background-color: #656565;
#   color: #f1f1f1;
# }
# #T_1866f_row2_col3 {
#   background-color: #505050;
#   color: #f1f1f1;
# }
# #T_1866f_row3_col1 {
#   background-color: #767676;
#   color: #f1f1f1;
# }
# #T_1866f_row3_col2 {
#   background-color: #b5b5b5;
#   color: #000000;
# }
# #T_1866f_row3_col3 {
#   background-color: #303030;
#   color: #f1f1f1;
# }
# #T_1866f_row4_col1 {
#   background-color: #c3c3c3;
#   color: #000000;
# }
# #T_1866f_row4_col3, #T_1866f_row8_col2, #T_1866f_row9_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_1866f_row5_col1 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_1866f_row5_col2 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_1866f_row5_col3 {
#   background-color: #030303;
#   color: #f1f1f1;
# }
# #T_1866f_row6_col1 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_1866f_row6_col2 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_1866f_row6_col3 {
#   background-color: #3f3f3f;
#   color: #f1f1f1;
# }
# #T_1866f_row7_col1 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_1866f_row7_col2 {
#   background-color: #afafaf;
#   color: #000000;
# }
# #T_1866f_row7_col3 {
#   background-color: #3d3d3d;
#   color: #f1f1f1;
# }
# #T_1866f_row8_col1 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_1866f_row8_col3 {
#   background-color: #7e7e7e;
#   color: #f1f1f1;
# }
# #T_1866f_row9_col2 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_1866f_row9_col3 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1866f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1866f_level0_col0" class="col_heading level0 col0" >Product ID</th>
#       <th id="T_1866f_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_1866f_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_1866f_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1866f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1866f_row0_col0" class="data row0 col0" >TEC-PH-3148</td>
#       <td id="T_1866f_row0_col1" class="data row0 col1" >86935.778600</td>
#       <td id="T_1866f_row0_col2" class="data row0 col2" >5921.578600</td>
#       <td id="T_1866f_row0_col3" class="data row0 col3" >171</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1866f_row1_col0" class="data row1 col0" >TEC-PH-3806</td>
#       <td id="T_1866f_row1_col1" class="data row1 col1" >76441.530600</td>
#       <td id="T_1866f_row1_col2" class="data row1 col2" >17238.520600</td>
#       <td id="T_1866f_row1_col3" class="data row1 col3" >139</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1866f_row2_col0" class="data row2 col0" >TEC-PH-5268</td>
#       <td id="T_1866f_row2_col1" class="data row2 col1" >73156.303000</td>
#       <td id="T_1866f_row2_col2" class="data row2 col2" >17027.113000</td>
#       <td id="T_1866f_row2_col3" class="data row2 col3" >134</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1866f_row3_col0" class="data row3 col0" >TEC-PH-5355</td>
#       <td id="T_1866f_row3_col1" class="data row3 col1" >71904.555500</td>
#       <td id="T_1866f_row3_col2" class="data row3 col2" >9938.195500</td>
#       <td id="T_1866f_row3_col3" class="data row3 col3" >147</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1866f_row4_col0" class="data row4 col0" >TEC-CO-3691</td>
#       <td id="T_1866f_row4_col1" class="data row4 col1" >61599.824000</td>
#       <td id="T_1866f_row4_col2" class="data row4 col2" >25199.928000</td>
#       <td id="T_1866f_row4_col3" class="data row4 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1866f_row5_col0" class="data row5 col0" >FUR-CH-4654</td>
#       <td id="T_1866f_row5_col1" class="data row5 col1" >58193.484100</td>
#       <td id="T_1866f_row5_col2" class="data row5 col2" >5997.254100</td>
#       <td id="T_1866f_row5_col3" class="data row5 col3" >169</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1866f_row6_col0" class="data row6 col0" >FUR-CH-5441</td>
#       <td id="T_1866f_row6_col1" class="data row6 col1" >50661.684000</td>
#       <td id="T_1866f_row6_col2" class="data row6 col2" >4710.984000</td>
#       <td id="T_1866f_row6_col3" class="data row6 col3" >141</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1866f_row7_col0" class="data row7 col0" >FUR-CH-4530</td>
#       <td id="T_1866f_row7_col1" class="data row7 col1" >50121.516000</td>
#       <td id="T_1866f_row7_col2" class="data row7 col2" >10427.326000</td>
#       <td id="T_1866f_row7_col3" class="data row7 col3" >142</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1866f_row8_col0" class="data row8 col0" >TEC-PH-5839</td>
#       <td id="T_1866f_row8_col1" class="data row8 col1" >48653.460000</td>
#       <td id="T_1866f_row8_col2" class="data row8 col2" >-198.090000</td>
#       <td id="T_1866f_row8_col3" class="data row8 col3" >108</td>
#     </tr>
#     <tr>
#       <th id="T_1866f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1866f_row9_col0" class="data row9 col0" >TEC-PH-5356</td>
#       <td id="T_1866f_row9_col1" class="data row9 col1" >47877.785700</td>
#       <td id="T_1866f_row9_col2" class="data row9 col2" >9465.325700</td>
#       <td id="T_1866f_row9_col3" class="data row9 col3" >96</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(Product_analysis['Product ID'], Product_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by Product ID')
plt.xlabel('Product ID')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(Product_analysis['Product ID'], Product_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by Product ID')
plt.xlabel('Product ID')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(Product_analysis['Product ID'], Product_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by Product ID')
plt.xlabel('Product ID')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Products like TEC-PH-3806 and TEC-PH-5268 demonstrate strong sales and high-profit margins, suggesting potential growth opportunities or competitive advantages in their respective markets.
# * Understanding sales and profit by product ID can inform product development, pricing strategies, and inventory management decisions to optimize performance and maximize profitability across product lines.

# %%
Product_analysis.query('Quantity == Quantity.max()')
# Out:
#     Product ID     Sales   Profit  Quantity
# 0  TEC-PH-3148 86,935.78 5,921.58       171

# %% [markdown]
# * OFF-FA-6129 emerges as the best-selling product, indicating high demand or popularity among customers.

# %%
Category_analysis = df.groupby('Category').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Category_analysis.sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_4dd8e_row0_col1, #T_4dd8e_row0_col2, #T_4dd8e_row2_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_4dd8e_row0_col3, #T_4dd8e_row1_col2, #T_4dd8e_row1_col3, #T_4dd8e_row2_col1 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_4dd8e_row1_col1 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_4dd8e_row2_col2 {
#   background-color: #bce5df;
#   color: #000000;
# }
# </style>
# <table id="T_4dd8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4dd8e_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_4dd8e_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_4dd8e_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_4dd8e_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4dd8e_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_4dd8e_row0_col0" class="data row0 col0" >Technology</td>
#       <td id="T_4dd8e_row0_col1" class="data row0 col1" >4744557.498080</td>
#       <td id="T_4dd8e_row0_col2" class="data row0 col2" >663778.733180</td>
#       <td id="T_4dd8e_row0_col3" class="data row0 col3" >35176</td>
#     </tr>
#     <tr>
#       <th id="T_4dd8e_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_4dd8e_row1_col0" class="data row1 col0" >Furniture</td>
#       <td id="T_4dd8e_row1_col1" class="data row1 col1" >4110451.898300</td>
#       <td id="T_4dd8e_row1_col2" class="data row1 col2" >285082.730200</td>
#       <td id="T_4dd8e_row1_col3" class="data row1 col3" >34892</td>
#     </tr>
#     <tr>
#       <th id="T_4dd8e_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_4dd8e_row2_col0" class="data row2 col0" >Office Supplies</td>
#       <td id="T_4dd8e_row2_col1" class="data row2 col1" >3787492.513500</td>
#       <td id="T_4dd8e_row2_col2" class="data row2 col2" >518595.827900</td>
#       <td id="T_4dd8e_row2_col3" class="data row2 col3" >108244</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(Category_analysis['Category'], Category_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(Category_analysis['Category'], Category_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Category')
plt.xlabel('Category')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(Category_analysis['Category'], Category_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Category')
plt.xlabel('Category')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Technology products contribute significantly to total sales and profit, highlighting their importance in the company's product portfolio and revenue generation.
# * Office Supplies demonstrate high sales volume but comparatively lower profitability, suggesting potential opportunities for cost optimization or pricing strategies to enhance profitability in this category.

# %%
Sub_Category_analysis = df.groupby('Sub-Category').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).reset_index()

# %%
Sub_Category_analysis.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_28e18_row0_col1, #T_28e18_row1_col2, #T_28e18_row9_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_28e18_row0_col2 {
#   background-color: #10746c;
#   color: #f1f1f1;
# }
# #T_28e18_row0_col3 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_28e18_row1_col1 {
#   background-color: #0a6f67;
#   color: #f1f1f1;
# }
# #T_28e18_row1_col3, #T_28e18_row15_col2 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_28e18_row2_col1 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_28e18_row2_col2 {
#   background-color: #aee0d8;
#   color: #000000;
# }
# #T_28e18_row2_col3 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_28e18_row3_col1 {
#   background-color: #187c74;
#   color: #f1f1f1;
# }
# #T_28e18_row3_col2 {
#   background-color: #7fccc0;
#   color: #000000;
# }
# #T_28e18_row3_col3, #T_28e18_row14_col2 {
#   background-color: #dbb972;
#   color: #000000;
# }
# #T_28e18_row4_col1 {
#   background-color: #a6dcd4;
#   color: #000000;
# }
# #T_28e18_row4_col2 {
#   background-color: #e6f1f0;
#   color: #000000;
# }
# #T_28e18_row4_col3 {
#   background-color: #58b0a7;
#   color: #f1f1f1;
# }
# #T_28e18_row5_col1 {
#   background-color: #d4ede9;
#   color: #000000;
# }
# #T_28e18_row5_col2 {
#   background-color: #abdfd7;
#   color: #000000;
# }
# #T_28e18_row5_col3 {
#   background-color: #ab6e1f;
#   color: #f1f1f1;
# }
# #T_28e18_row6_col1 {
#   background-color: #f6ecd3;
#   color: #000000;
# }
# #T_28e18_row6_col2 {
#   background-color: #f1e1b5;
#   color: #000000;
# }
# #T_28e18_row6_col3 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# #T_28e18_row7_col1 {
#   background-color: #f6ebcd;
#   color: #000000;
# }
# #T_28e18_row7_col2, #T_28e18_row7_col3, #T_28e18_row16_col1 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_28e18_row8_col1 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_28e18_row8_col2 {
#   background-color: #c7eae5;
#   color: #000000;
# }
# #T_28e18_row8_col3 {
#   background-color: #f6ecd1;
#   color: #000000;
# }
# #T_28e18_row9_col1 {
#   background-color: #ca9849;
#   color: #f1f1f1;
# }
# #T_28e18_row9_col2 {
#   background-color: #f6ebcf;
#   color: #000000;
# }
# #T_28e18_row10_col1 {
#   background-color: #b97b29;
#   color: #f1f1f1;
# }
# #T_28e18_row10_col2 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_28e18_row10_col3 {
#   background-color: #f6edd7;
#   color: #000000;
# }
# #T_28e18_row11_col1 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_28e18_row11_col2, #T_28e18_row13_col2 {
#   background-color: #f1dfb3;
#   color: #000000;
# }
# #T_28e18_row11_col3 {
#   background-color: #73c3b8;
#   color: #000000;
# }
# #T_28e18_row12_col1, #T_28e18_row13_col1 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_28e18_row12_col2 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_28e18_row12_col3 {
#   background-color: #ddbe78;
#   color: #000000;
# }
# #T_28e18_row13_col3 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_28e18_row14_col1 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_28e18_row14_col3 {
#   background-color: #d8b46c;
#   color: #000000;
# }
# #T_28e18_row15_col1 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_28e18_row15_col3 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_28e18_row16_col2 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_28e18_row16_col3 {
#   background-color: #e8d097;
#   color: #000000;
# }
# </style>
# <table id="T_28e18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28e18_level0_col0" class="col_heading level0 col0" >Sub-Category</th>
#       <th id="T_28e18_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_28e18_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_28e18_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28e18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28e18_row0_col0" class="data row0 col0" >Phones</td>
#       <td id="T_28e18_row0_col1" class="data row0 col1" >1706824.139200</td>
#       <td id="T_28e18_row0_col2" class="data row0 col2" >216717.005800</td>
#       <td id="T_28e18_row0_col3" class="data row0 col3" >11870</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28e18_row1_col0" class="data row1 col0" >Copiers</td>
#       <td id="T_28e18_row1_col1" class="data row1 col1" >1509436.273280</td>
#       <td id="T_28e18_row1_col2" class="data row1 col2" >258567.548180</td>
#       <td id="T_28e18_row1_col3" class="data row1 col3" >7454</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28e18_row2_col0" class="data row2 col0" >Chairs</td>
#       <td id="T_28e18_row2_col1" class="data row2 col1" >1501681.764200</td>
#       <td id="T_28e18_row2_col2" class="data row2 col2" >140396.267500</td>
#       <td id="T_28e18_row2_col3" class="data row2 col3" >12336</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28e18_row3_col0" class="data row3 col0" >Bookcases</td>
#       <td id="T_28e18_row3_col1" class="data row3 col1" >1466572.241800</td>
#       <td id="T_28e18_row3_col2" class="data row3 col2" >161924.419500</td>
#       <td id="T_28e18_row3_col3" class="data row3 col3" >8310</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28e18_row4_col0" class="data row4 col0" >Storage</td>
#       <td id="T_28e18_row4_col1" class="data row4 col1" >1126812.969400</td>
#       <td id="T_28e18_row4_col2" class="data row4 col2" >108416.680600</td>
#       <td id="T_28e18_row4_col3" class="data row4 col3" >16884</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_28e18_row5_col0" class="data row5 col0" >Appliances</td>
#       <td id="T_28e18_row5_col1" class="data row5 col1" >1010535.525000</td>
#       <td id="T_28e18_row5_col2" class="data row5 col2" >141562.587700</td>
#       <td id="T_28e18_row5_col3" class="data row5 col3" >6026</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_28e18_row6_col0" class="data row6 col0" >Machines</td>
#       <td id="T_28e18_row6_col1" class="data row6 col1" >779060.067100</td>
#       <td id="T_28e18_row6_col2" class="data row6 col2" >58867.873000</td>
#       <td id="T_28e18_row6_col3" class="data row6 col3" >4906</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_28e18_row7_col0" class="data row7 col0" >Tables</td>
#       <td id="T_28e18_row7_col1" class="data row7 col1" >757041.924400</td>
#       <td id="T_28e18_row7_col2" class="data row7 col2" >-64083.388700</td>
#       <td id="T_28e18_row7_col3" class="data row7 col3" >3083</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_28e18_row8_col0" class="data row8 col0" >Accessories</td>
#       <td id="T_28e18_row8_col1" class="data row8 col1" >749237.018500</td>
#       <td id="T_28e18_row8_col2" class="data row8 col2" >129626.306200</td>
#       <td id="T_28e18_row8_col3" class="data row8 col3" >10946</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_28e18_row9_col0" class="data row9 col0" >Binders</td>
#       <td id="T_28e18_row9_col1" class="data row9 col1" >461869.393700</td>
#       <td id="T_28e18_row9_col2" class="data row9 col2" >72433.151600</td>
#       <td id="T_28e18_row9_col3" class="data row9 col3" >21403</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_28e18_row10_col0" class="data row10 col0" >Furnishings</td>
#       <td id="T_28e18_row10_col1" class="data row10 col1" >385155.967900</td>
#       <td id="T_28e18_row10_col2" class="data row10 col2" >46845.431900</td>
#       <td id="T_28e18_row10_col3" class="data row10 col3" >11163</td>
#     </tr>
#     <tr>
#       <th id="T_28e18_level0_row11" class="row_heading level0 row11" >11</th>

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(Sub_Category_analysis['Sub-Category'], Sub_Category_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales')

plt.subplot(2, 2, 2)
plt.bar(Sub_Category_analysis['Sub-Category'], Sub_Category_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Profit')

plt.subplot(2, 2, 3)
plt.bar(Sub_Category_analysis['Sub-Category'], Sub_Category_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Sub-categories like Phones, Copiers, and Chairs demonstrate strong sales performance and profitability, suggesting potential growth opportunities or competitive advantages in their respective markets.
# * Addressing challenges in sub-categories like Tables, where profitability is negative, may require review or adjustment of pricing strategies, cost structures, or product offerings to improve performance and sustainability

# %%
Sub_Category_analysis.query('Quantity == Quantity.max()')
# Out:
#   Sub-Category      Sales    Profit  Quantity
# 9      Binders 461,869.39 72,433.15     21403

# %% [markdown]
# * Binders emerge as the most sold sub-category, indicating high demand or popularity among customers.

# %%
Return_analysis = df.groupby('Product ID').agg({
    'Returned': 'count',
}).sort_values(by='Returned', ascending=False)

# %%
Return_analysis.head(10).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_8207f_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_8207f_row1_col0 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_8207f_row2_col0 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_8207f_row3_col0 {
#   background-color: #774508;
#   color: #f1f1f1;
# }
# #T_8207f_row4_col0 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_8207f_row5_col0 {
#   background-color: #6a3d07;
#   color: #f1f1f1;
# }
# #T_8207f_row6_col0 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_8207f_row7_col0, #T_8207f_row8_col0 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_8207f_row9_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8207f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8207f_level0_col0" class="col_heading level0 col0" >Returned</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product ID</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8207f_level0_row0" class="row_heading level0 row0" >OFF-FA-6129</th>
#       <td id="T_8207f_row0_col0" class="data row0 col0" >227</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row1" class="row_heading level0 row1" >OFF-BI-3737</th>
#       <td id="T_8207f_row1_col0" class="data row1 col0" >92</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row2" class="row_heading level0 row2" >OFF-ST-4057</th>
#       <td id="T_8207f_row2_col0" class="data row2 col0" >90</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row3" class="row_heading level0 row3" >OFF-ST-5693</th>
#       <td id="T_8207f_row3_col0" class="data row3 col0" >84</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row4" class="row_heading level0 row4" >OFF-BI-4828</th>
#       <td id="T_8207f_row4_col0" class="data row4 col0" >83</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row5" class="row_heading level0 row5" >OFF-AR-5923</th>
#       <td id="T_8207f_row5_col0" class="data row5 col0" >80</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row6" class="row_heading level0 row6" >OFF-ST-6033</th>
#       <td id="T_8207f_row6_col0" class="data row6 col0" >77</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row7" class="row_heading level0 row7" >OFF-BI-2917</th>
#       <td id="T_8207f_row7_col0" class="data row7 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row8" class="row_heading level0 row8" >OFF-AR-6120</th>
#       <td id="T_8207f_row8_col0" class="data row8 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_8207f_level0_row9" class="row_heading level0 row9" >OFF-BI-3293</th>
#       <td id="T_8207f_row9_col0" class="data row9 col0" >74</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Product ID: OFF-FA-6129:
# * Records the highest number of returns, totaling 227 units.
# * Understanding the products with the highest number of returns can provide valuable insights into potential quality issues, customer preferences, or market trends.

# %%
df[['Category','Sub-Category']][df['Product ID'].isin(['OFF-FA-6129'])].head()
# Out:
#             Category Sub-Category
# 28   Office Supplies    Fasteners
# 138  Office Supplies    Fasteners
# 337  Office Supplies    Fasteners
# 778  Office Supplies    Fasteners
# 942  Office Supplies    Fasteners

# %%
discount_analysis = df.groupby('Discount').agg({'Sales': 'mean', 'Profit': 'mean'}).reset_index().sort_values(by='Sales', ascending=False).style.background_gradient(cmap='Blues')
discount_analysis
# Out:
# <style type="text/css">
# #T_795ad_row0_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_795ad_row0_col1, #T_795ad_row1_col2, #T_795ad_row10_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_795ad_row0_col2, #T_795ad_row17_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_795ad_row1_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_795ad_row1_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_795ad_row2_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_795ad_row2_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_795ad_row2_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_795ad_row3_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_795ad_row3_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_795ad_row3_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_795ad_row4_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_795ad_row4_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_795ad_row4_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_795ad_row5_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_795ad_row5_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_795ad_row5_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_795ad_row6_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_795ad_row6_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_795ad_row6_col2 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_795ad_row7_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_795ad_row7_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_795ad_row7_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_795ad_row8_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_795ad_row8_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_795ad_row8_col2 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_795ad_row9_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_795ad_row9_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_795ad_row9_col2 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_795ad_row10_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_795ad_row10_col2, #T_795ad_row14_col0, #T_795ad_row23_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_795ad_row11_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_795ad_row11_col1, #T_795ad_row12_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_795ad_row11_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_795ad_row12_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_795ad_row12_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_795ad_row13_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_795ad_row13_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_795ad_row13_col2, #T_795ad_row23_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_795ad_row14_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_795ad_row14_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_795ad_row15_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_795ad_row15_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_795ad_row15_col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_795ad_row16_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_795ad_row16_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_795ad_row16_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_795ad_row17_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_795ad_row17_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_795ad_row18_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_795ad_row18_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_795ad_row18_col2, #T_795ad_row19_col2 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_795ad_row19_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_795ad_row19_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_795ad_row20_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_795ad_row20_col1, #T_795ad_row21_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_795ad_row20_col2 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_795ad_row21_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_795ad_row21_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_795ad_row22_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_795ad_row22_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_795ad_row22_col2 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_795ad_row23_col2 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_795ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_795ad_level0_col0" class="col_heading level0 col0" >Discount</th>
#       <th id="T_795ad_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_795ad_level0_col2" class="col_heading level0 col2" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_795ad_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_795ad_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_795ad_row0_col1" class="data row0 col1" >1273.214250</td>
#       <td id="T_795ad_row0_col2" class="data row0 col2" >-551.595750</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_795ad_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_795ad_row1_col1" class="data row1 col1" >810.779022</td>
#       <td id="T_795ad_row1_col2" class="data row1 col2" >140.990022</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_795ad_row2_col0" class="data row2 col0" >35</td>
#       <td id="T_795ad_row2_col1" class="data row2 col1" >784.479406</td>
#       <td id="T_795ad_row2_col2" class="data row2 col2" >-116.144693</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row3" class="row_heading level0 row3" >18</th>
#       <td id="T_795ad_row3_col0" class="data row3 col0" >57</td>
#       <td id="T_795ad_row3_col1" class="data row3 col1" >678.733500</td>
#       <td id="T_795ad_row3_col2" class="data row3 col2" >-526.129000</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_795ad_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_795ad_row4_col1" class="data row4 col1" >630.865800</td>
#       <td id="T_795ad_row4_col2" class="data row4 col2" >-315.067200</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_795ad_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_795ad_row5_col1" class="data row5 col1" >565.674387</td>
#       <td id="T_795ad_row5_col2" class="data row5 col2" >50.602409</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_795ad_row6_col0" class="data row6 col0" >30</td>
#       <td id="T_795ad_row6_col1" class="data row6 col1" >555.682421</td>
#       <td id="T_795ad_row6_col2" class="data row6 col2" >-57.899557</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_795ad_row7_col0" class="data row7 col0" >32</td>
#       <td id="T_795ad_row7_col1" class="data row7 col1" >536.794770</td>
#       <td id="T_795ad_row7_col2" class="data row7 col2" >-88.560656</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_795ad_row8_col0" class="data row8 col0" >25</td>
#       <td id="T_795ad_row8_col1" class="data row8 col1" >444.723977</td>
#       <td id="T_795ad_row8_col2" class="data row8 col2" >4.043371</td>
#     </tr>
#     <tr>
#       <th id="T_795ad_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_795ad_row9_col0" class="data row9 col0" >37</td>
#       <td id="T_795ad_row9_col1" class="data row9 col1" >427.270512</td>

# %%
discount_analysis = df.groupby('Discount').agg({'Sales': 'mean', 'Profit': 'mean'}).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Discount', y='value', hue='variable', data=pd.melt(discount_analysis, id_vars='Discount'), palette='muted')

plt.xticks(rotation=90)
plt.xlabel('Discount Presence')
plt.ylabel('Average Value')
plt.title('Effect of Discounts on Sales and Profit')

plt.show()

# %% [markdown]
# * Discounts can drive sales volume but may not always translate into increased profitability, as seen in cases of high discounts resulting in negative profits.
# * Analyzing the impact of discounts on sales and profit can help in optimizing pricing strategies to balance revenue generation and profit margins effectively.
# * Identifying the most effective discount levels that maximize sales while maintaining acceptable profit margins is crucial for sustainable business growth.

# %%
Shipp_analysis = df.groupby('Product ID').agg({
    'Shipping Cost': 'sum',
}).sort_values(by='Shipping Cost', ascending=False)

# %%
Shipp_analysis.head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_d7d84_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d7d84_row1_col0 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_d7d84_row2_col0 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_d7d84_row3_col0 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_d7d84_row4_col0 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_d7d84_row5_col0 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_d7d84_row6_col0 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_d7d84_row7_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_d7d84_row8_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_d7d84_row9_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d7d84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7d84_level0_col0" class="col_heading level0 col0" >Shipping Cost</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product ID</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7d84_level0_row0" class="row_heading level0 row0" >TEC-PH-5268</th>
#       <td id="T_d7d84_row0_col0" class="data row0 col0" >8817.331000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row1" class="row_heading level0 row1" >TEC-PH-3148</th>
#       <td id="T_d7d84_row1_col0" class="data row1 col0" >8027.715000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row2" class="row_heading level0 row2" >TEC-PH-5355</th>
#       <td id="T_d7d84_row2_col0" class="data row2 col0" >7852.663000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row3" class="row_heading level0 row3" >TEC-PH-3806</th>
#       <td id="T_d7d84_row3_col0" class="data row3 col0" >7065.166000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row4" class="row_heading level0 row4" >FUR-CH-4530</th>
#       <td id="T_d7d84_row4_col0" class="data row4 col0" >6548.165000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row5" class="row_heading level0 row5" >TEC-PH-5839</th>
#       <td id="T_d7d84_row5_col0" class="data row5 col0" >5892.074000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row6" class="row_heading level0 row6" >FUR-CH-4654</th>
#       <td id="T_d7d84_row6_col0" class="data row6 col0" >5751.541000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row7" class="row_heading level0 row7" >TEC-PH-5356</th>
#       <td id="T_d7d84_row7_col0" class="data row7 col0" >5321.110000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row8" class="row_heading level0 row8" >FUR-CH-5378</th>
#       <td id="T_d7d84_row8_col0" class="data row8 col0" >5191.842000</td>
#     </tr>
#     <tr>
#       <th id="T_d7d84_level0_row9" class="row_heading level0 row9" >FUR-CH-5441</th>
#       <td id="T_d7d84_row9_col0" class="data row9 col0" >5141.734000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Product ID: TEC-PH-5268:
#  - Incurs the highest shipping cost at $8817.33.
#  - High shipping costs for certain products may impact overall profitability and pricing strategies, requiring optimization measures.

# %%
order_analysis = df.groupby('Ship Mode').agg({
    'Order Priority': 'count',
}).sort_values(by='Order Priority', ascending=False).reset_index()
order_analysis
# Out:
#         Ship Mode  Order Priority
# 0  Standard Class           30775
# 1    Second Class           10309
# 2     First Class            7505
# 3        Same Day            2701

# %% [markdown]
# - Standard Class appears to be the most commonly chosen shipping option, suggesting it may be the most cost-effective or efficient for most orders

# %% [markdown]
# ## Conclusion: ##
#
# * Sales and Profitability:
# 1. Total sales and profitability have shown steady growth over the years, with significant increases observed in 2014 and 2015.
# 2. The technology category contributes the most to sales, followed by furniture and office supplies.
# 3. Phones, copiers, and chairs are the top-selling sub-categories, contributing significantly to overall sales and profit.
# 4. Binders and office furniture (FUR-CH) are the top-selling products, indicating strong demand in these categories.
#
#
# * Customer Segments and Regions:
# 1. The consumer segment generates the highest sales and profit, followed by corporate and home office segments.
# 2. Western Europe, Central America, and Oceania are the top-performing regions in terms of sales and profit, suggesting potential areas for expansion or increased focus.
#
# * Shipping Dynamics:
# 1. Standard class shipping is the most preferred mode, indicating the importance of cost-effective shipping options for customers.
# 2. The majority of orders are prioritized as medium, suggesting a balance between cost and delivery speed.
#
# * Discount and Return Analysis:
# 1. Most orders are made without any discount, indicating competitive pricing strategies or minimal promotional activities.
# 2. The return rate is relatively low, with the majority of products not being returned, reflecting good product quality or effective customer service.

# %% [markdown]
# conclusion, a comprehensive understanding of sales, profitability, and shipping dynamics is crucial for making informed business decisions and optimizing operational efficiency. By leveraging insights from this analysis, businesses can enhance customer satisfaction, streamline logistics, and drive overall profitability.
