# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\adity\Documents\Python Script\file handle\EDA\Diwali.csv",encoding="unicode_escape")

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.nunique()
# Out:
# User_ID             3755
# Cust_name           1250
# Product_ID          2351
# Gender                 2
# Age Group              7
# Age                   81
# Marital_Status         2
# State                 16
# Zone                   5
# Occupation            15
# Product_Category      18
# Orders                 4
# Amount              6584
# Status                 0
# unnamed1               0
# dtype: int64

# %%
for col in df.columns:
    print(f"{col}:{df[col].unique()}")
# Out:
# User_ID:[1002903 1000732 1001990 ... 1001542 1004378 1005258]
# Cust_name:['Sanskriti' 'Kartik' 'Bindu' ... 'Chris' 'Madan Mohan' 'Nicole']
# Product_ID:['P00125942' 'P00110942' 'P00118542' ... 'P00307142' 'P00044742'
#  'P00296942']
# Gender:['F' 'M']
# Age Group:['26-35' '0-17' '18-25' '55+' '46-50' '51-55' '36-45']
# Age:[28 35 16 25 61 26 34 20 46 24 48 29 54 19 30 53 83 33 40 39 32 36 55 27
#  72 45 43 47 22 52 18 21 38 37 23 49 42 50 31 44 41 66 15 51 77 87 79 71
#  88 58 82 62 92 12 63 17 13 67 90 56 75 81 64 73 84 14 76 86 89 68 91 85
#  70 80 65 74 69 78 57 60 59]
# Marital_Status:[0 1]
# State:['Maharashtra' 'Andhra\xa0Pradesh' 'Uttar Pradesh' 'Karnataka' 'Gujarat'
#  'Himachal Pradesh' 'Delhi' 'Madhya Pradesh' 'Jharkhand' 'Kerala'
#  'Haryana' 'Bihar' 'Rajasthan' 'Uttarakhand' 'Telangana' 'Punjab']
# Zone:['Western' 'Southern' 'Central' 'Northern' 'Eastern']
# Occupation:['Healthcare' 'Govt' 'Automobile' 'Construction' 'Food Processing'
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %%
df1=df.drop(['User_ID','Status','unnamed1'],axis=1)

# %%
df1.head()
# Out:
#    Cust_name Product_ID Gender Age Group  Age  Marital_Status           State  \
# 0  Sanskriti  P00125942      F     26-35   28               0     Maharashtra
# 1     Kartik  P00110942      F     26-35   35               1  Andhra Pradesh
# 2      Bindu  P00118542      F     26-35   35               1   Uttar Pradesh
# 3     Sudevi  P00237842      M      0-17   16               0       Karnataka
# 4       Joni  P00057942      M     26-35   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
df1['Amount'].fillna(df1['Amount'].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.shape
# Out:
# (11243, 12)

# %%
df1['Age Group'].unique()
# Out:
# array(['26-35', '0-17', '18-25', '55+', '46-50', '51-55', '36-45'],
#       dtype=object)

# %%
df1['Age_Category']=df1['Age Group'].replace({'0-17':'Tean','18-25':'Young','26-35':'Adult','36-45':'Adult','46-50':'Middle Age','51-55':'Middle Age','55+':'Senior'})

# %%
df1['Gender'].replace({'F':'Female','M':'Male'},inplace=True)
df1['State'].replace({'Andhra\xa0Pradesh':'Andhra Prandesh'},inplace=True)

# %%
df1['State'].unique()
# Out:
# array(['Maharashtra', 'Andhra Prandesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Madhya Pradesh',
#        'Jharkhand', 'Kerala', 'Haryana', 'Bihar', 'Rajasthan',
#        'Uttarakhand', 'Telangana', 'Punjab'], dtype=object)

# %%
df1.describe().T
# Out:
#                   count         mean          std    min     25%     50%  \
# Age             11243.0    35.422841    12.756369   12.0    27.0    33.0
# Marital_Status  11243.0     0.420261     0.493623    0.0     0.0     0.0
# Orders          11243.0     2.488749     1.114960    1.0     1.0     2.0
# Amount          11243.0  9454.084476  5218.941128  188.0  5444.0  8111.0
#
#                     75%      max
# Age                43.0     92.0
# Marital_Status      1.0      1.0
# Orders              3.0      4.0
# Amount          12672.0  23952.0

# %%
df1.describe(include='object').T
# Out:
#                   count unique                 top  freq
# Cust_name         11243   1250            Vishakha    42
# Product_ID        11243   2351           P00265242    53
# Gender            11243      2              Female  7838
# Age Group         11243      7               26-35  4538
# State             11243     16       Uttar Pradesh  1944
# Zone              11243      5             Central  4294
# Occupation        11243     15           IT Sector  1586
# Product_Category  11243     18  Clothing & Apparel  2653
# Age_Category      11243      5               Adult  6823

# %%
cat_cols=df1.select_dtypes(exclude=['int','float']).columns.tolist()
num_cols=df1.select_dtypes(include=np.number).columns.tolist()
print("categorical Variables:")
print(cat_cols)
print("Numberical variable:")
print(num_cols)
# Out:
# categorical Variables:
# ['Cust_name', 'Product_ID', 'Gender', 'Age Group', 'State', 'Zone', 'Occupation', 'Product_Category', 'Age_Category']
# Numberical variable:
# ['Age', 'Marital_Status', 'Orders', 'Amount']

# %%
for col in num_cols:
    print(col)
    plt.figure(figsize=(15,4))
    
    plt.subplot(1,2,1)
    sns.histplot(df1[col],kde=True,alpha=0.5,bins=20,edgecolor='black')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    
    plt.subplot(1,2,2)
    sns.boxplot(x=df1[col])
    plt.xlabel(col)
    
    plt.show()
# Out:
# Age
# Marital_Status
# Orders
# Amount

# %%
for col in cat_cols:
    sns.countplot(x=col,data=df1,order=df1[col].value_counts().head(10).index,palette='Set2')
    plt.ylabel('Count')
    plt.xticks(rotation=90)
    plt.title(col,fontsize=15,fontweight='bold',color='blue')
    plt.show()

# %%
df1.groupby(['Product_ID']).agg({'Amount':'sum'}).head(1)
# Out:
#               Amount
# Product_ID
# P00000142   248716.0

# %%
top_selling=df1[df1['Product_ID']=='P00000142'].groupby('Product_Category')['Amount'].sum()
print(top_selling.max())
# Out:
# 125793.0

# %%
df1['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing & Apparel       2653
# Food                     2493
# Electronics & Gadgets    2082
# Footwear & Shoes         1064
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 353
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                       99
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
df1['Product_ID'].value_counts().head()
# Out:
# Product_ID
# P00265242    53
# P00110942    44
# P00184942    37
# P00237542    35
# P00112142    34
# Name: count, dtype: int64

# %%
df1['Product_ID'].value_counts().tail()
# Out:
# Product_ID
# P00326042    1
# P00255342    1
# P00347942    1
# P00273642    1
# P00035742    1
# Name: count, dtype: int64

# %%
search_title="P00265242"
result=df1[df1['Product_ID'].str.contains(search_title,case=False)]
result
# Out:
#         Cust_name Product_ID  Gender Age Group  Age  Marital_Status  \
# 62          Bruce  P00265242  Female     26-35   33               0
# 208        Murray  P00265242  Female     46-50   50               1
# 349           Ann  P00265242  Female     26-35   32               0
# 591         Craig  P00265242  Female       55+   63               0
# 812        Jeremy  P00265242  Female     18-25   20               1
# 963        Dipali  P00265242    Male     51-55   53               1
# 1309      Akshata  P00265242  Female     26-35   35               0
# 1347       Hughes  P00265242  Female     36-45   38               0
# 1561       Steven  P00265242  Female      0-17   12               0
# 1630       Cortes  P00265242  Female       55+   81               1
# 1796        Laura  P00265242  Female     26-35   30               1
# 1864        Rohan  P00265242  Female     26-35   28               1
# 2110    Shrichand  P00265242    Male     36-45   41               1
# ...

# %%
print(f"Net sales {round(df1['Amount'].sum())}")
# Out:
# Net sales 106292272

# %%
total_order_ID=df1.groupby('Product_ID')['Orders'].sum().nlargest(1)
total_order_ID
# Out:
# Product_ID
# P00265242    127
# Name: Orders, dtype: int64

# %%
total_order_zone=df1.groupby('Zone')['Orders'].sum().sort_values(ascending=False)
total_order_zone
# Out:
# Zone
# Central     10636
# Southern     6744
# Western      4866
# Northern     3724
# Eastern      2011
# Name: Orders, dtype: int64

# %%
total_order_zone.index
# Out:
# Index(['Central', 'Southern', 'Western', 'Northern', 'Eastern'], dtype='object', name='Zone')

# %%
total_order_zone=df1.groupby('Zone')['Orders'].sum().sort_values(ascending=False)
total_order_state=df1.groupby('State')['Orders'].sum().sort_values(ascending=False).head()
total_order_category=df1.groupby('Product_Category')['Orders'].sum().sort_values(ascending=False).head()
total_order_ID=df1.groupby('Product_ID')['Orders'].sum().sort_values(ascending=False).head()

plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)
plt.pie(total_order_zone, labels=total_order_zone.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Zone Vs Orders")

plt.subplot(2, 2, 2)
plt.pie(total_order_state, labels=total_order_state.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Top 5 State Vs Orders")

plt.subplot(2, 2, 3)
plt.pie(total_order_category, labels=total_order_category.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Top 5 Product_Category Vs Orders")

plt.subplot(2, 2, 4)
plt.pie(total_order_ID, labels=total_order_ID.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Top 5 Product_ID Vs Orders")

plt.tight_layout()
plt.show()

# %%
total_order_zone=df1.groupby('Zone')['Orders'].sum().sort_values(ascending=False)
total_order_state=df1.groupby('State')['Orders'].sum().sort_values(ascending=False).tail()
total_order_category=df1.groupby('Product_Category')['Orders'].sum().sort_values(ascending=False).tail()
total_order_ID=df1.groupby('Product_ID')['Orders'].sum().sort_values(ascending=False).tail()

plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)
plt.pie(total_order_zone, labels=total_order_zone.index, autopct='%1.f%%', colors=sns.color_palette("Set1"))
plt.title("Zone Vs Orders")

plt.subplot(2, 2, 2)
plt.pie(total_order_state, labels=total_order_state.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Bottom 5 State Vs Orders")

plt.subplot(2, 2, 3)
plt.pie(total_order_category, labels=total_order_category.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Bottom 5 Product_Category Vs Orders")

plt.subplot(2, 2, 4)
plt.pie(total_order_ID, labels=total_order_ID.index, autopct='%1.f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'lightgray'])
plt.title("Bottom 5 Product_ID Vs Orders")

plt.tight_layout()
plt.show()

# %%
state_sale=df1.groupby('State')['Amount'].sum().sort_values(ascending=False).head(10)
value=plt.bar(state_sale.index,state_sale.values,color='skyblue')
plt.bar_label(value,fmt='%.f',rotation=90,label_type="center")
plt.ticklabel_format(style='plain',axis='y')
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Top 10 States  by Sales')
plt.xticks(rotation=90)
plt.show()

# %%
fig, axarr = plt.subplots(4, 2, figsize=(18, 24))

df.groupby('State')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[0][0], fontsize=12, color='skyblue')
axarr[0][0].set_title("Location Vs Price", fontsize=10)

df.groupby('Zone')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[0][1], fontsize=12, color='lightcoral')
axarr[0][1].set_title("Zone Vs Price", fontsize=10)

df.groupby('Product_Category')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[1][0], fontsize=12, color='lightcoral')
axarr[1][0].set_title("Product_Category Vs Price", fontsize=10)

df.groupby('Product_ID')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[1][1], fontsize=12, color='lightgreen')
axarr[1][1].set_title("Product_ID Vs Price", fontsize=10)

df.groupby('Orders')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][0], fontsize=12, color='lightgreen')
axarr[2][0].set_title("Orders Vs Price", fontsize=10)

df.groupby('Age Group')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][1], fontsize=12, color='gold')
axarr[2][1].set_title("Age Group Vs Price", fontsize=10)

df.groupby('Gender')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[3][0], fontsize=12, color='lightblue')
axarr[3][0].set_title("Gender Vs Orders", fontsize=10)

df.groupby('Marital_Status')['Amount'].sum().sort_values(ascending=False).head(10).plot.bar(ax=axarr[3][1], fontsize=12, color='gold')
axarr[3][1].set_title("Car_Marital_StatusAge Vs Price", fontsize=10)

plt.tight_layout()
plt.show()
